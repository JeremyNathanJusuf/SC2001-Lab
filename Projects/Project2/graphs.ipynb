# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('./results/compare.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17332\3485021780.py in <module>
# ----> 1 df = pd.read_csv('./results/compare.csv')
#       2 df.head()
#
# c:\Users\jerem\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
f = plt.figure()
plt.plot(df['V'], df['matrix'])
plt.plot(df['V'], df['list'])

# %%
sparse = pd.read_csv('./results/compareSparsity.csv')
sparse.head()
# Out:
#    edges     d1    d2
# 0    100  71925   779
# 1    200  83704  1921
# 2    300  80294  2397
# 3    400  75112  1203
# 4    500  74194  2024

# %%
x = 600
f = plt.figure()
plt.plot(sparse['edges'][:x], sparse['d1'][:x])
plt.plot(sparse['edges'][:x], sparse['d2'][:x])
