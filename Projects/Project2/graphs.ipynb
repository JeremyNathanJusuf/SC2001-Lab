# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('./results/compare.csv')
df.head()
# Out:
#       V      matrix        list
# 0  1000  40607200.0  29864900.0
# 1  1100  55883100.0  39765500.0
# 2  1200  54299000.0  56729300.0
# 3  1300  52825800.0  48941400.0
# 4  1400  82892100.0  67986600.0

# %%
df = df[:66]

# %%
f = plt.figure()
plt.plot(df['V'], df['matrix'])
plt.plot(df['V'], df['list'])
